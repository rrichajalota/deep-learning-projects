# %% [markdown]
# # Most dominant color extraction
# 1. Get the image using cv2 (rgb format)
# 2. Define number of clusters (dominant colors)
# 3. Convert to RGB vector space
# 4. Initialize KMeans clusters
# 5. Cluster centers are dominant colors

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import pandas as pd
import cv2
from sklearn.cluster import KMeans

# %%
im = cv2.imread('./im1.jpg')
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
print im.shape
plt.figure(0)
plt.imshow(im)
plt.show()
# Out:
# (2000, 3000, 3)

# %%
img = cv2.resize(im, (1080, 720)) #cols- 1080 rows- 720
print img.shape
plt.figure(0)
plt.axis("off")
plt.imshow(img)
plt.show()
# Out:
# (720, 1080, 3)

# %%
#transform the image to rgb vector space
image_vector = img.reshape((img.shape[0] * img.shape[1], img.shape[2]))
print image_vector.shape
# Out:
# (777600, 3)

# %%
NC= 16
km = KMeans(n_clusters=NC)
km.fit(image_vector)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=16, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
colors = 255 - km.cluster_centers_.astype("uint8")
plt.figure(0)
for cols in range(colors.shape[0]):
    cl = np.zeros((20, 20, 3))
    cl[:, :, :] = colors[cols]
    plt.subplot(1, NC, cols+1)
    plt.axis("off")
    plt.imshow(cl)
plt.show()

# %%
new_im = np.zeros((image_vector.shape))

for ix in range(new_im.shape[0]):
    new_im[ix, :] = colors[km.labels_[ix]]

new_im = new_im.reshape(img.shape)

plt.figure(0)
plt.axis("off")
plt.imshow(new_im)
plt.show()

# %%
dom_cols = np.unique(km.labels_, return_counts=True)
lab = dom_cols[0]
hist = dom_cols[1].astype("float")/dom_cols[1].sum()

# %%
col_sp = np.zeros((100, 500, 3))

start = 0
for (col, percent) in zip(lab, hist):
    # print percent
    end = int(start + percent*col_sp.shape[1])
    # print end
    col_sp[:, start:end, :] = colors[col]
    start = end

plt.figure(0)
plt.axis("off")
plt.imshow(col_sp)

plt.show()
